# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')

# %%
data.sample(5)
# Out:
#            Country                           Region  Happiness Rank  \
# 55       Lithuania       Central and Eastern Europe              56
# 48         Bahrain  Middle East and Northern Africa              49
# 153         Rwanda               Sub-Saharan Africa             154
# 85         Romania       Central and Eastern Europe              86
# 14   United States                    North America              15
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 55             5.833         0.03843                   1.14723  1.25745
# 48             5.960         0.05412                   1.32376  1.21624
# 153            3.465         0.03464                   0.22208  0.77370
# 85             5.124         0.06607                   1.04345  0.88588
# 14             7.119         0.03839                   1.39451  1.24711
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
data.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data.tail(5)
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
Observation 
# Happiness Score is our Target Value & other Input value

# %%
data.shape
# Out:
# (158, 12)

# %%
# obsevation
# columns no->  12, Row nos->   158

# %% [markdown]
# ### Cheking missing data in dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
# no missing values are in all datasets

# %% [markdown]
# ### Cheking how distribute the data

# %%
data.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# ### Drop the columns of cuntry & Region due to not impotant for analysis

# %%
# drop two column
data1=data.drop(['Country','Region'],axis=1)

# %% [markdown]
# ###

# %% [markdown]
# ### See in graph how to distribute the data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(10,12))
plotnumber=1
for i in data1:
    plotnumber<=10
    ax=plt.subplot(2,5,plotnumber)
    sns.distplot(data1[i])
    plt.xlabel(i,fontsize=10)
    
    plotnumber+=1
plt.show()

# %%
# Observation
# data distribuion of all columns are normal distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### cheking correlation between target value & Feature

# %%
data.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
corr_mat=data.corr()
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(), annot=True,)
plt.title('correlation')
plt.show()

# %%
# Observation 
# Correlation is good with target value (Happiness score) of all feature

# %%
x=data1.drop(['Happiness Score'], axis=1)
y=data1['Happiness Score']

# %%
x.columns
# Out:
# Index(['Happiness Rank', 'Standard Error', 'Economy (GDP per Capita)',
#        'Family', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# ### Checking Outlier in all feature

# %%
plt.figure(figsize=(12,14))
plotnumber=1
for column in x:
    if plotnumber<=9:
        plt.subplot(3,3,plotnumber)
        ax=sns.boxplot(x[column])
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.show()

# %%
# # Obsevation
# 1. Standard Error- Have outlier
# 2. Trust- Outlier is showinh
# 3. Generosity-Outlier is showinh
# 4. Dystopia Residual-Outlier is showing
# 5. Family-Outlier is showing

# %%
plt.figure(figsize=(12,14))
plotnumber=1
for column in x:
    if plotnumber<=9:
        plt.subplot(3,3,plotnumber)
        ax=sns.distplot(x[column])
        plt.xlabel(column, fontsize=20)
    plotnumber+=1
    
plt.show()

# %% [markdown]
# ###  Handeling the outlier

# %%
q1=data1.quantile(0.25)

# %%
q3=data1.quantile(0.75)

# %%
iqr=q3-q1
iqr
# Out:
# Happiness Rank                   78.500000
# Happiness Score                   1.717750
# Standard Error                    0.015032
# Economy (GDP per Capita)          0.612640
# Family                            0.357582
# Health (Life Expectancy)          0.371828
# Freedom                           0.220762
# Trust (Government Corruption)     0.118580
# Generosity                        0.159330
# Dystopia Residual                 0.703005
# dtype: float64

# %%
higher_side=q3+(1.5*iqr)

# %%
lower_side=q1-(1.5*iqr)

# %%
high_ste=q3.iloc[2] + (1.5*iqr.iloc[2])
high_ste
# Out:
# 0.07484874999999999

# %%
index_ste=np.where(data['Standard Error']>high_ste)
index_ste
# Out:
# (array([ 39,  40,  62,  64,  93,  96, 100, 115, 125, 156], dtype=int64),)

# %%
df=data1.drop(data1.index[index_ste])

# %%
df.shape
# Out:
# (148, 10)

# %%
high_trst=q3.iloc[7] + (1.5*iqr.iloc[7])
high_trst
# Out:
# 0.35812499999999997

# %%
index_trst=np.where(data1['Trust (Government Corruption)']>high_trst)

# %%
df=data1.drop(data1.index[index_trst])

# %%
df.shape
# Out:
# (144, 10)

# %%
higher_gen=q3.Generosity + (1.5*iqr.Generosity)
index_gen=np.where(data1['Generosity']>higher_gen)
df=data1.drop(data1.index[index_gen])
df.shape
# Out:
# (156, 10)

# %%
df.reset_index()
# Out:
#      index  Happiness Rank  Happiness Score  Standard Error  \
# 0        0               1            7.587         0.03411
# 1        1               2            7.561         0.04884
# 2        2               3            7.527         0.03328
# 3        3               4            7.522         0.03880
# 4        4               5            7.427         0.03553
# ..     ...             ...              ...             ...
# 151    153             154            3.465         0.03464
# 152    154             155            3.340         0.03656
# 153    155             156            3.006         0.05015
# 154    156             157            2.905         0.08658
# 155    157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# ...

# %% [markdown]
# ###  Handeling Skewness

# %% [markdown]
# ### Cheking Skewness

# %%
x.skew().sort_values()
# Out:
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Economy (GDP per Capita)        -0.317575
# Dystopia Residual               -0.238911
# Happiness Rank                   0.000418
# Generosity                       1.001961
# Trust (Government Corruption)    1.385463
# Standard Error                   1.983439
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer()

# %%
x_new=pt.fit_transform(x)

# %%
pd.DataFrame(x_new, columns=x.columns).skew().sort_values(ascending=True)
# Out:
# Happiness Rank                  -0.264365
# Health (Life Expectancy)        -0.183181
# Family                          -0.169651
# Economy (GDP per Capita)        -0.127233
# Freedom                         -0.080728
# Standard Error                  -0.020092
# Generosity                       0.013320
# Dystopia Residual                0.022925
# Trust (Government Corruption)    0.185965
# dtype: float64

# %% [markdown]
# ### Create model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
lr=LinearRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=44)
lr=lr.fit(x_train,y_train)
pred_train=lr.predict(x_test)

# %%
lr.score(x_train,y_train)
# Out:
# 0.999999939054037

# %%
lr.score(x_test,y_test)
# Out:
# 0.9999999492451627

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mean_squared_error(y_test,pred_train)
# Out:
# 6.187249414233811e-08

# %%
mean_absolute_error(y_test,pred_train)
# Out:
# 0.0002078626185440746
