# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/avocado.csv')
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1         1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2         2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3         3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4         4.0  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#      year  region
# 0  2015.0  Albany
# 1  2015.0  Albany
# 2  2015.0  Albany
# ...

# %%
data.sample(2)
# Out:
#       Unnamed: 0 Date  AveragePrice  Total Volume  4046  4225  4770  \
# 9993         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 9125         NaN  NaN           NaN           NaN   NaN   NaN   NaN
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags type  year region
# 9993         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 9125         NaN         NaN         NaN          NaN  NaN   NaN    NaN

# %%
# Drop the unnamed: 0 column 
data=data.drop(['Unnamed: 0'],axis=1)

# %%
# find shape the data ( no.of columns & rows)
data.shape
# Out:
# (16468, 13)

# %%
# find the Nan value
data.isna().sum()
# Out:
# Date            14951
# AveragePrice    14951
# Total Volume    14951
# 4046            14951
# 4225            14951
# 4770            14951
# Total Bags      14951
# Small Bags      14951
# Large Bags      14951
# XLarge Bags     14951
# type            14951
# year            14951
# region          14951
# dtype: int64

# %%
# Observation
#  every columns has 14951 numbers Nan value.abs

# %%
data=data.dropna()  # drop the NaN value

# %%
data.sample(5)
# Out:
#             Date  AveragePrice  Total Volume      4046       4225      4770  \
# 1390  01-05-2016          1.05     716003.18   4764.79  520369.75  54779.30
# 111   09-08-2015          1.16     821523.45  56362.75  557363.94  42933.87
# 339   29-11-2015          1.11     228427.08  84236.03   38244.11  63664.14
# 1339  11-09-2016          0.89      89822.98  41793.11    1783.77   6411.87
# 577   31-05-2015          1.00      92345.33   7195.55   58910.38   1622.81
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 1390   136089.34   136034.89       54.45         0.00  conventional  2016.0
# 111    164862.89   161564.81     3298.08         0.00  conventional  2015.0
# 339     42282.80    31628.56      920.38      9733.86  conventional  2015.0
# 1339    39834.23    38898.96      927.29         7.98  conventional  2016.0
# 577     24616.59    11607.93    12647.23       361.43  conventional  2015.0
#
#                    region
# ...

# %%
data.shape # now column=1517 & Row=13
# Out:
# (1517, 13)

# %%
# Observation
#  every columns has 14951 numbers Nan value.abs

# %%
data.isna().sum()  # now No NaN present in dataset
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
# find data informations
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1516
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1517 non-null   object
#  1   AveragePrice  1517 non-null   float64
#  2   Total Volume  1517 non-null   float64
#  3   4046          1517 non-null   float64
#  4   4225          1517 non-null   float64
#  5   4770          1517 non-null   float64
#  6   Total Bags    1517 non-null   float64
#  7   Small Bags    1517 non-null   float64
#  8   Large Bags    1517 non-null   float64
#  9   XLarge Bags   1517 non-null   float64
#  10  type          1517 non-null   object
#  11  year          1517 non-null   float64
#  12  region        1517 non-null   object
# dtypes: float64(10), object(3)
# memory usage: 165.9+ KB

# %%
# Observation 
#  date- it is object value
#  type- it is object value
# region- it is object value
#  rest all columns are float value

# %%
data['type'].value_counts() # type only one (conventional)
# Out:
# conventional    1517
# Name: type, dtype: int64

# %%
# Using encoder to convert object to number
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df=le.fit_transform(data['region'])
data['region']=df
data
# Out:
#             Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0     27-12-2015          1.33      64236.62   1036.74   54454.85     48.16
# 1     20-12-2015          1.35      54876.98    674.28   44638.81     58.33
# 2     13-12-2015          0.93     118220.22    794.70  109149.67    130.50
# 3     06-12-2015          1.08      78992.15   1132.00   71976.41     72.58
# 4     29-11-2015          1.28      51039.60    941.48   43838.39     75.78
# ...          ...           ...           ...       ...        ...       ...
# 1512  16-10-2016          1.39     190846.01  57529.11   56366.66  17531.78
# 1513  09-10-2016          1.51     178235.75  43325.87   52189.61  19419.57
# 1514  02-10-2016          1.48     178410.82  46364.75   52893.38  16736.92
# 1515  25-09-2016          1.47     189131.52  54110.79   53593.58  17495.42
# 1516  18-09-2016          1.43     182978.30  43116.41   54193.42  16563.91
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df=le.fit_transform(data['type'])
data['type']=df
data
# Out:
#             Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0     27-12-2015          1.33      64236.62   1036.74   54454.85     48.16
# 1     20-12-2015          1.35      54876.98    674.28   44638.81     58.33
# 2     13-12-2015          0.93     118220.22    794.70  109149.67    130.50
# 3     06-12-2015          1.08      78992.15   1132.00   71976.41     72.58
# 4     29-11-2015          1.28      51039.60    941.48   43838.39     75.78
# ...          ...           ...           ...       ...        ...       ...
# 1512  16-10-2016          1.39     190846.01  57529.11   56366.66  17531.78
# 1513  09-10-2016          1.51     178235.75  43325.87   52189.61  19419.57
# 1514  02-10-2016          1.48     178410.82  46364.75   52893.38  16736.92
# 1515  25-09-2016          1.47     189131.52  54110.79   53593.58  17495.42
# 1516  18-09-2016          1.43     182978.30  43116.41   54193.42  16563.91
#
# ...

# %%
# cheking type of region
data['region'].value_counts(ascending=True)
# Out:
# 21     3
# 40     9
# 43     9
# 20    10
# 33    12
# 27    12
# 16    13
# 30    13
# 39    15
# 45    16
# 35    16
# 18    16
# 23    17
# 37    17
# 10    17
# 14    18
# 24    18
# 46    19
# 15    19
# 36    21
# 29    21
# 32    22
# 13    23
# 8     23
# 41    24
# 11    24
# 48    25
# 25    25
# 50    27
# 17    29
# 28    29
# 34    30
# 7     31
# 47    34
# 22    34
# 49    36
# 38    38
# 42    39
# 12    40
# 19    41
# 26    44
# 9     47
# 44    49
# 5     51
# 31    52
# 1     54
# 4     62
# 3     65
# 2     65
# 0     67
# 6     76
# Name: region, dtype: int64

# %%
# Describe the dataset for Observation
data.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags    type  \
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000  1517.0
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074     0.0
# ...

# %%
# Observation
# AveragePrice-no NaN->Mean & std is okay, data distribution is normal.
# Total Volume-no NaN->Mean & std is not okay, data distribution is normal. there may outlier and skebness.
# 4046-no NaN->Mean & std is not okay, data distribution is normal. there may outlier and skebness.
# 4225-no NaN->Mean & std is not okay, data distribution is normal. there may outlier and skebness.
# 4770-no NaN->Mean & std is not okay, data distribution is normal. there may outlier and skebness.
# Total Bags-no NaN->Mean & std is not okay, data distribution is normal. there may outlier and skebness.
# Large Bags-no NaN->Mean & std is not okay, data distribution is normal. there may outlier and skebness.
# XLarge Bags-no NaN->Mean & std is not okay, data distribution is not normal. there are outlier and skebness.
# Type-no NaN->type is one

# %%
# drop date colume
data=data.drop(['Date'],axis=1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
# cheking data distribution
# cheking & confirm data is normal distributed
plt.figure(figsize=(14,14),facecolor='y')
plotnumber=1
for i in data:
    if plotnumber<=13:
        ax=plt.subplot(3,5,plotnumber)
        sns.distplot(data[i])
        plt.xlabel(i,fontsize=10)
        
    plotnumber+=1
    
plt.show()

# %%
# Observation
# AveragePrice- data distribution is normal.range-0.3 to 0.17
# Total Volume- data distribution is normal.range-0 to 1 there are skebness.
# 4046- data distribution is normal.range-0 to 0.5 there are outlier and skebness.
# 4225- data distribution is normal.range-0 to 0.5 there are outlier and skebness.
# 4770- data distribution is normal.range-0 to 0.5 there are outlier and skebness.
# Total Bags- data distribution is normal.range-0 to 2.0 there may outlier and skebness.
# Small Bags- data distribution is normal.range-0 to 1.0 there may outlier and skebness.
# Large Bags- data distribution is normal.range-0 to 0.3 there may outlier and skebness.
# XLarge Bags- data distribution is not normal.range-0 to 20000 there are outlier and skebness.

# %%
# cheking Outlier using box plot.
plt.figure(figsize=(12,14))
plotnumber=1
for column in data:
    if plotnumber<=17:
        ax=plt.subplot(4,5,plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column, fontsize=15)
        
    plotnumber+=1
plt.show()

# %%
# observation
# all column has outlier

# %%
# handel outlier by using quantile technque

# %%
# Column name
data.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'region'],
#       dtype='object')

# %%
# for getting iqr

# q3=data.quantile(0.75)
# q1=data.quantile(0.25)
# iqr=q3-q1

# %%
# #  handle Outlir Total Volumn column
# higher_volumn=q3.iloc[2] +(1.5*iqr.iloc[2])  # find hiher side outlier
# higher_volumn

# %%
# index=np.where(data['Total Volume']>higher_volumn)     # find index number of higher outlier
# data=data.drop(data.index[index])          # drop the index
# data.reset_index()                     # reset index of data
# data.shape                             # shape the data

# %%
# #  handle Outlir 4046 column
# higher=q3.iloc[3]+(1.5*iqr.iloc[3])  # find hiher side outlier
# higher

# %%
# index=np.where(data['4046']>higher)     # find index number of higher outlier
# data=data.drop(data.index[index])          # drop the index
# data.reset_index()                     # reset index of data
# data.shape                             # shape the data

# %%
# #  handle Outlir 4225 column
# higher=q3.iloc[4]+(1.5*iqr.iloc[4])  # find hiher side outlier
# print(higher)

# index=np.where(data['4225']>higher)     # find index number of higher outlier
# data=data.drop(data.index[index])          # drop the index
# data.reset_index()                     # reset index of data
# data.shape

# %%
# #  handle Outlir 4770 column
# higher=q3.iloc[5]+(1.5*iqr.iloc[5])  # find hiher side outlier
# print(higher)

# index=np.where(data['4770']>higher)     # find index number of higher outlier
# data=data.drop(data.index[index])          # drop the index
# data.reset_index()                     # reset index of data
# data.shape

# %%
# #  handle Outlir Total Bags column
# higher=q3.iloc[6]+(1.5*iqr.iloc[6])  # find hiher side outlier
# print(higher)

# index=np.where(data['Total Bags']>higher)     # find index number of higher outlier
# data=data.drop(data.index[index])          # drop the index
# data.reset_index()                     # reset index of data
# data.shape

# %%
# #  handle Outlir Small Bags column
# higher=q3.iloc[7]+(1.5*iqr.iloc[7])  # find hiher side outlier
# print(higher)

# index=np.where(data['Total Bags']>higher)     # find index number of higher outlier
# data=data.drop(data.index[index])          # drop the index
# data.reset_index()                     # reset index of data
# data.shape

# %%
# #  handle Outlir Small Bags column
# higher=q3.iloc[8]+(1.5*iqr.iloc[8])  # find hiher side outlier
# print(higher)

# index=np.where(data['Large Bags']>higher)     # find index number of higher outlier
# data=data.drop(data.index[index])          # drop the index
# data.reset_index()                     # reset index of data
# data.shape

# %%
# #  handle Outlir XLarge Bags' column
# higher=q3.iloc[9]+(1.5*iqr.iloc[9])  # find hiher side outlier
# print(higher)

# index=np.where(data['XLarge Bags']>higher)     # find index number of higher outlier
# data=data.drop(data.index[index])          # drop the index
# data.reset_index()                     # reset index of data
# data.shape

# %%
# cheking data distribution
# cheking & confirm data is normal distributed
plt.figure(figsize=(14,14),facecolor='y')
plotnumber=1
for i in data:
    if plotnumber<=13:
        ax=plt.subplot(3,5,plotnumber)
        sns.distplot(data[i])
        plt.xlabel(i,fontsize=10)
        
    plotnumber+=1
    
plt.show()

# %%
data.shape
# Out:
# (1517, 12)

# %%
# check outlier droped using boxplot
plt.figure(figsize=(12,14))
plotnumber=1
for column in data:
    if plotnumber<=17:
        ax=plt.subplot(4,5,plotnumber)
        sns.boxplot(data[column])
        plt.xlabel(column, fontsize=15)
        
    plotnumber+=1
plt.show()

# %%
# co rrelationship between feature & lable
data.corr().abs()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000      0.140470  0.190096  0.092084  0.100567
# Total Volume      0.140470      1.000000  0.985568  0.987154  0.934347
# 4046              0.190096      0.985568  1.000000  0.951952  0.898570
# 4225              0.092084      0.987154  0.951952  1.000000  0.927757
# 4770              0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags        0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags        0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags        0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags       0.048284      0.521717  0.474063  0.504718  0.646053
# type                   NaN           NaN       NaN       NaN       NaN
# year              0.178683      0.004189  0.040439  0.007254  0.029222
# region            0.229408      0.236579  0.269481  0.215733  0.138092
#
# ...

# %%
data=data.drop(['XLarge Bags','type'],axis=1) # drop xlarge box & type due to NaN value

# %%
# co rrelationship between feature & lable
data.corr().abs()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000      0.140470  0.190096  0.092084  0.100567
# Total Volume      0.140470      1.000000  0.985568  0.987154  0.934347
# 4046              0.190096      0.985568  1.000000  0.951952  0.898570
# 4225              0.092084      0.987154  0.951952  1.000000  0.927757
# 4770              0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags        0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags        0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags        0.177480      0.910226  0.884229  0.900496  0.840523
# year              0.178683      0.004189  0.040439  0.007254  0.029222
# region            0.229408      0.236579  0.269481  0.215733  0.138092
#
#               Total Bags  Small Bags  Large Bags      year    region
# AveragePrice    0.111597    0.097682    0.177480  0.178683  0.229408
# ...

# %%
# correlation show with heatmap
plt.figure(figsize=(16,10))
sns.heatmap(data.corr().abs(),annot=True)
plt.savefig('correlation baseball.jpg')
plt.show()

# %%
# observation
# AveragePrice vs region- relationship 18%. Relation is good
# AveragePrice vs year- relationship 55%  Relation is good
# AveragePrice vs Large Bags- relationship 7.3%  Relation is good
# AveragePrice vs small Bags- relationship 21%  Relation is good
# AveragePrice vs Total Bags- relationship 22%  Relation is good
# AveragePrice vs 4770- relationship 15%  Relation is good
# AveragePrice vs 4225- relationship 22%  Relation is good
# AveragePrice vs 4046- relationship 31%  Relation is good
# AveragePrice vs Total Volumn- relationship 10%  Relation is good

# %%
x=data.drop(['AveragePrice'],axis=1)
y=data.AveragePrice

# %%
# handel multicolinearity problem
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=pd.DataFrame()
vif['vif']=[variance_inflation_factor(x,i) for i in range(x.shape[1])]
vif['feature']=x.columns
vif
# Out:
#             vif       feature
# 0           inf  Total Volume
# 1           inf          4046
# 2           inf          4225
# 3           inf          4770
# 4           inf    Total Bags
# 5  2.026018e+04    Small Bags
# 6  6.467740e+02    Large Bags
# 7  3.114549e+00          year
# 8  3.351894e+00        region

# %%
# Observation  
#  will take all column to create model

# %%
# checking relationship between feature & lable
plt.figure(figsize=(12,14),facecolor='y')
plotnumber=1
for column in x:
    if plotnumber<=13:
        ax=plt.subplot(4,5,plotnumber)
        sns.scatterplot(x[column],y)
        plt.xlabel(column, fontsize=15)
        plt.ylabel('AveragePrice')
        
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(12,14),facecolor='y')
plotnumber=1
for column in x:
    if plotnumber<=17:
        ax=plt.subplot(4,5,plotnumber)
        sns.lineplot(x[column],y)
        plt.xlabel(column, fontsize=15)
        plt.ylabel('AveragePrice')
        
    plotnumber+=1
plt.show()

# %%
# Observation
# All column has positive & good relasionship

# %%
# cheking Skewness
x.skew().sort_values(ascending=False)
# Out:
# 4225            6.394926
# Total Volume    6.200138
# 4046            6.051830
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# year            1.828332
# region          0.288146
# dtype: float64

# %%
# minimize the skewness using power transformer
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
x_new=pt.fit_transform(x)

# %%
x=pd.DataFrame(x_new,columns=x.columns)  
x.skew().sort_values(ascending=False)   # minimize skewness as before & arranging ascending order.
# Out:
# year            1.828332
# Total Volume    0.071159
# Small Bags      0.027632
# 4225            0.008450
# Total Bags      0.005205
# 4046           -0.012059
# 4770           -0.032945
# Large Bags     -0.074795
# region         -0.209568
# dtype: float64

# %%
# check skew minimize or not with graph

plt.figure(figsize=(12,14),facecolor='y')
plotnumber=1
for column in x:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(x[column])
        plt.xlabel(column, fontsize=15)
        
    plotnumber+=1
plt.show()

# %%
# Observation
# Standarized the data

# %%
x.shape
# Out:
# (1517, 9)

# %%
# Standarized the data using by standers Scaler
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scler=scaler.fit_transform(x)   # standarized the feature data

# %%
#  Train test spilt the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train, y_test=train_test_split(x_scler,y,test_size=0.25,random_state=88)

# %%
# Create Regression Ml Model
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
pred=lm.predict(x_test)

# %%
# cheking score of model using r2
from sklearn.metrics import r2_score

print('Testing Score  ',r2_score(y_test,pred)*100)
# Out:
# Testing Score   33.30595534784834

# %%
print('Training Score  ',lm.score(x_train,y_train)*100)
# Out:
# Training Score   37.136921017923065

# %%
# Import KNN Regressor
from sklearn.neighbors import KNeighborsRegressor

# %%
# Difine function to get train & test Result
def metric_score(reg, x_train,x_test,y_train,y_test,train=True):
    if train:
        pred=reg.predict(x_train)
        print('\n------Train Result--------')
        print(f'R2 score:{r2_score(y_train,pred)*100:.2f}%')
        
    elif train==False:
        pred=reg.predict(x_test)
        print('\n------Test Result--------')
        print(f'R2 score:{r2_score(y_test,pred)*100:.2f}%')

# %%
knn=KNeighborsRegressor()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
# Call the function for Train Result & Test Result
metric_score(knn,x_train,x_test,y_train,y_test,train=True)
metric_score(knn,x_train,x_test,y_train,y_test,train=False)
# Out:
# ------Train Result--------
# R2 score:89.02%
#
# ------Test Result--------
# R2 score:83.30%

# %%
# cheking model overfitting
from sklearn.model_selection import cross_val_score
cross_val_score(knn,x_scler,y).mean() # cross validetion score
# Out:
# 0.0681583294253058

# %%
# Observation: cross validation score is coming 7%

# %%
# Hyperperameter tuning use for improve the result
from sklearn.model_selection import GridSearchCV

# %%
# fixed the parameter 
param={'algorithm':['kd_tree','brute'],
      'leaf_size':[10,12,14,15,16,18,19,20],
      'n_neighbors':[9,11,13,15,17,19,21]}

# %%
grid=GridSearchCV(estimator=knn,param_grid=param)  # create Gridsearch CV model & train the data in it
grid.fit(x_train,y_train) 

grid.best_params_  # finding best parameters through Gridsearcv
# Out:
# {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 9}

# %%
knn=KNeighborsRegressor(algorithm = 'kd_tree', leaf_size = 10, n_neighbors = 9) # use best parameters in KNN model

knn.fit(x_train,y_train) # train the data
# Out:
# KNeighborsRegressor(algorithm='kd_tree', leaf_size=10, n_neighbors=9)

# %%
# call the function to get train result & test Result to improve the model result
metric_score(knn,x_train,x_test,y_train,y_test,train=True)
metric_score(knn,x_train,x_test,y_train,y_test,train=False)
# Out:
# ------Train Result--------
# R2 score:82.81%
#
# ------Test Result--------
# R2 score:80.25%

# %%
# Observation
# Result is good.

# %%
# create DecisionTreeRegressor model
from sklearn.tree import DecisionTreeRegressor

# %%
# Difine function to get train & test Result
def metric_score(reg, x_train,x_test,y_train,y_test,train=True):
    if train:
        pred=reg.predict(x_train)
        print('\n------Train Result--------')
        print(f'R2 score:{r2_score(y_train,pred)*100:.2f}%')
        
    elif train==False:
        pred1=reg.predict(x_test)
        print('\n------Test Result--------')
        print(f'R2 score:{r2_score(y_test,pred1)*100:.2f}%')

# %%
de_reg=DecisionTreeRegressor()
de_reg.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
# call the function to get train result & test Result to improve the model result
metric_score(de_reg,x_train,x_test,y_train,y_test,train=True)
metric_score(de_reg,x_train,x_test,y_train,y_test,train=False)
# Out:
# ------Train Result--------
# R2 score:100.00%
#
# ------Test Result--------
# R2 score:72.04%

# %%
# Observation
# Model is good. But May it overfitting

# %%
# cheking model underfitting or overfitting
from sklearn.model_selection import cross_val_score
cross_val_score(de_reg,x_scler,y,cv=5).mean()
# Out:
# -0.41379452727615984

# %%
# Hyperperameter Tuning to improve result

# %%
from sklearn.model_selection import GridSearchCV

# %%
# fixed the parameter to find best parameter
param={'criterion':['gini','entropy'],
      'max_depth':[3,10],
      'min_samples_leaf':[2,9],
      'min_samples_split':[2,8],
      'max_leaf_nodes':[2,10]}

# %%
grid_search=GridSearchCV(estimator=de_reg,param_grid=param,cv=2)

# %%
# grid_search.fit(x_train,y_train)

# %%
# Create Random Forest model
from sklearn.ensemble import RandomForestRegressor

# %%
def matrics_score(rer,x_train,x_test,y_train,y_test,train=True):
    if train:
        pred=reg.predict(x_train)
        print('--------Train Result-------')
        print(f'Accuracy score:{r2_score(y_train,pred)*100:0.2f}%')
    elif train ==False:
        pred=reg.predict(x_test)
        print('--------Test Result-------')
        print(f'Accuracy score:{r2_score(y_test,pred)*100:0.2f}%')

# %%
ran=RandomForestRegressor()
ran.fit(x_train,y_train)  # train tthe data
# Out:
# RandomForestRegressor()

# %%
# call the function to get train result & test Result to improve the model result
metric_score(ran,x_train,x_test,y_train,y_test,train=True)
metric_score(ran,x_train,x_test,y_train,y_test,train=False)
# Out:
# ------Train Result--------
# R2 score:97.43%
#
# ------Test Result--------
# R2 score:82.47%

# %%
# Observetion
# model is working good

# %%
# Hyperperameter Tuning to improve result
from sklearn.model_selection import GridSearchCV

# %%
# fixed the parameter to find best parameter
param={'n_estimators':[2,3,5,6,7,8,10],
       'criterion':['entropy','gini'],
       'max_depth':[3,5],
       'min_samples_leaf':[2,5],
       'min_samples_split':[2,5],
       'max_leaf_nodes':[2,7]}

# %%
grd=GridSearchCV(estimator=ran,param_grid=param)
# grd.fit(x_train,y_train)

# %%
# Model Valuation of Random Forest model
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
ran_pred=ran.predict(x_test)
dt_pred=de_reg.predict(x_test)
knn_pred=knn.predict(x_test)
lm_pred=lm.predict(x_test)

# %%
# find MAE error
print('randomforest  -->', mean_absolute_error(y_test,ran_pred))
print('Dtree --.', mean_absolute_error(y_test,dt_pred))
print('knn MAE -->', mean_absolute_error(y_test,knn_pred))
print('Linear MAE -->', mean_absolute_error(y_test,lm_pred))
# Out:
# randomforest  --> 0.05660052631578951
# Dtree --. 0.0705
# knn MAE --> 0.06317251461988303
# Linear MAE --> 0.11611341101857352

# %%
# Observation
# RandomForest MAE error is 5.7%
# DecissionTree MAE error is 7.1%
# Knn MAE error is 6.3%
# Linear MAE error is 11.6%

# RandomForest model's MAE error is lower than other. so it is good

# %%
# find MSE error
print('randomforest  -->', mean_squared_error(y_test,ran_pred))
print('Dtree --.', mean_squared_error(y_test,dt_pred))
print('knn MAE -->', mean_squared_error(y_test,knn_pred))
print('Linear MAE -->', mean_squared_error(y_test,lm_pred))
# Out:
# randomforest  --> 0.0061911656842105305
# Dtree --. 0.009874999999999998
# knn MAE --> 0.00697366146848603
# Linear MAE --> 0.023553071611294777

# %%
# Observation
# RandomForest MSE error is 0.65%
# DecissionTree MSE error is 0.99%
# Knn MSE error is 0.69%
# Linear MAE error is 2.4%

# RandomForest model's MSE error is lower than other. so it is good

# %%
# find RMSE error
print('randomforest  -->', np.sqrt(mean_squared_error(y_test,ran_pred)))
print('Dtree --.', np.sqrt(mean_squared_error(y_test,dt_pred)))
print('knn MAE -->', np.sqrt(mean_squared_error(y_test,knn_pred)))
print('Linear MAE -->', np.sqrt(mean_squared_error(y_test,lm_pred)))
# Out:
# randomforest  --> 0.07868396078115622
# Dtree --. 0.09937303457175894
# knn MAE --> 0.08350845147939237
# Linear MAE --> 0.15347010005631317

# %%
# Observation
# RandomForest RMSE error is 8.07%
# DecissionTree RMSE error is 9.97%
# Knn RMSE error is 8.35%
# Linear MAE error is 15.34%

# RandomForest model's RMSE error is lower than other. so it is good

# %%
# save model 
import pickle
pickle.dump(ran,open('randomForest_model','wb'))

# %% [markdown]
# ### Create Classification Model

# %%
x1=data.drop(['region'],axis=1)
y1=data.region

# %%
# checking relationship between feature & lable
plt.figure(figsize=(12,14),facecolor='y')
plotnumber=1
for column in x1:
    if plotnumber<=13:
        ax=plt.subplot(4,5,plotnumber)
        sns.scatterplot(x1[column],y1)
        plt.xlabel(column, fontsize=15)
        plt.ylabel('region')
        
    plotnumber+=1
plt.show()

# %%
# checking relationship between feature & lable
plt.figure(figsize=(12,14),facecolor='y')
plotnumber=1
for column in x1:
    if plotnumber<=13:
        ax=plt.subplot(4,5,plotnumber)
        sns.lineplot(x1[column],y1)
        plt.xlabel(column, fontsize=15)
        plt.ylabel('region')
        
    plotnumber+=1
plt.show()

# %%
# cheking Skewness
x1.skew().sort_values(ascending=False)
# Out:
# 4225            6.394926
# Total Volume    6.200138
# 4046            6.051830
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# year            1.828332
# AveragePrice   -0.109444
# dtype: float64

# %%
# minimize the skewness using power transformer
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
x1_new=pt.fit_transform(x1)

x1=pd.DataFrame(x1_new,columns=x1.columns)  
x1.skew().sort_values(ascending=False)   # minimize skewness as before & arranging ascending order.
# Out:
# year            1.828332
# Total Volume    0.071159
# Small Bags      0.027632
# AveragePrice    0.021101
# 4225            0.008450
# Total Bags      0.005205
# 4046           -0.012059
# 4770           -0.032945
# Large Bags     -0.074795
# dtype: float64

# %%
# checking relationship between feature & lable
plt.figure(figsize=(12,14),facecolor='y')
plotnumber=1
for column in x1:
    if plotnumber<=13:
        ax=plt.subplot(4,5,plotnumber)
        sns.distplot(x1[column])
        plt.xlabel(column, fontsize=15)
      
        
    plotnumber+=1
plt.show()

# %%
x1.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'year'],
#       dtype='object')

# %%
# Standarized the data using by standers Scaler
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x1_scler=scaler.fit_transform(x1)   # standarized the feature data

# %%
#  Train test spilt the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train, y_test=train_test_split(x1_scler,y,test_size=0.25,random_state=88)

# %%
# Difine function to get train & test Result
def metric_score(reg, x_train,x_test,y_train,y_test,train=True):
    if train:
        pred=reg.predict(x_train)
        print('\n------Train Result--------')
        print(f'R2 score:{r2_score(y_train,pred)*100:.2f}%')
        
    elif train==False:
        pred=reg.predict(x_test)
        print('\n------Test Result--------')
        print(f'R2 score:{r2_score(y_test,pred)*100:.2f}%')

# %%
# Import KNN Regressor
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier

# %%
knn.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [117], in <cell line: 1>()
# ----> 1 knn.fit(x_train,y_train)
#
# TypeError: fit() missing 1 required positional argument: 'y'
