# %%
import numpy as np
import pandas as pd

# %%
dt=pd.read_csv(r"C:\Users\ACER\Desktop\DT\DT Project\Evaluation Project\HR data\ibm-hr-analytics-employee-attrition-performance\WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
dt.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
dt.shape  # Column=1470 and Rows=35
# Out:
# (1470, 35)

# %%
# Find Nan Value is present or not
dt.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Observation
# No NaN value is present in data set

# %%
# Cheking Data informations
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# Observation
# Attrition,BusinessTravel,DailyRate, DistanceFromHome,EducationField,Gender,JobRole,MaritalStatus,Over18,OverTime columns are stirng value. we will convert in number from string using encoder technique.
# all rest coluns are integer values.

# %%
# Cheking unique value
dt['Attrition'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
dt['Attrition'].value_counts()  # cheking Value Count
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df=le.fit_transform(dt['Attrition'])   # Attrition column convert into number
dt['Attrition']=df
dt.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# dt=pd.get_dummies(dt[['Attrition','BusinessTravel','DailyRate', 'DistanceFromHome','EducationField','Gender','JobRole','MaritalStatus','Over18','OverTime']])
# dt.head()

# %%
df=le.fit_transform(dt['BusinessTravel'])   # 'BusinessTravel' column convert into number
dt['BusinessTravel']=df
dt.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate              Department  \
# 0   41          1               2       1102                   Sales
# 1   49          0               1        279  Research & Development
# 2   37          1               2       1373  Research & Development
# 3   33          0               1       1392  Research & Development
# 4   27          0               2        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df=le.fit_transform(dt['DailyRate'])   # 'DailyRate' column convert into number
dt['DailyRate']=df
dt.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate              Department  \
# 0   41          1               2        624                   Sales
# 1   49          0               1        113  Research & Development
# 2   37          1               2        805  Research & Development
# 3   33          0               1        820  Research & Development
# 4   27          0               2        312  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df=le.fit_transform(dt['Department'])   # Department column convert into number
dt['Department']=df
dt.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2        624           2                 1
# 1   49          0               1        113           1                 8
# 2   37          1               2        805           1                 2
# 3   33          0               1        820           1                 3
# 4   27          0               2        312           1                 2
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
# 1          1  Life Sciences              1               2  ...
# 2          2          Other              1               4  ...
# 3          4  Life Sciences              1               5  ...
# 4          1        Medical              1               7  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
# ...

# %%
df=le.fit_transform(dt['EducationField'])   # EducationField column convert into number
dt['EducationField']=df
dt.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2        624           2                 1
# 1   49          0               1        113           1                 8
# 2   37          1               2        805           1                 2
# 3   33          0               1        820           1                 3
# 4   27          0               2        312           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df=le.fit_transform(dt['Gender'])   # Gender column convert into number
dt['Gender']=df
dt.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2        624           2                 1
# 1   49          0               1        113           1                 8
# 2   37          1               2        805           1                 2
# 3   33          0               1        820           1                 3
# 4   27          0               2        312           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
dt['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
df=le.fit_transform(dt['JobRole'])   # JobRole column convert into number
dt['JobRole']=df
dt.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2        624           2                 1
# 1   49          0               1        113           1                 8
# 2   37          1               2        805           1                 2
# 3   33          0               1        820           1                 3
# 4   27          0               2        312           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
df=le.fit_transform(dt['MaritalStatus'])   # Maritalstatus column convert into number
dt['MaritalStatus']=df
dt.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2        624           2                 1
# 1   49          0               1        113           1                 8
# 2   37          1               2        805           1                 2
# 3   33          0               1        820           1                 3
# 4   27          0               2        312           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
df=le.fit_transform(dt['Over18'])   # Over18 column convert into number
dt['Over18']=df
dt.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2        624           2                 1
# 1   49          0               1        113           1                 8
# 2   37          1               2        805           1                 2
# 3   33          0               1        820           1                 3
# 4   27          0               2        312           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
dt['OverTime'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df=le.fit_transform(dt['OverTime'])   # OverTime column convert into number
dt['OverTime']=df
dt.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2        624           2                 1
# 1   49          0               1        113           1                 8
# 2   37          1               2        805           1                 2
# 3   33          0               1        820           1                 3
# 4   27          0               2        312           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
dt.describe()
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810     0.161224        1.607483   443.074830     1.260544
# std       9.135373     0.367863        0.665455   253.513199     0.527792
# min      18.000000     0.000000        0.000000     0.000000     0.000000
# 25%      30.000000     0.000000        1.000000   225.000000     1.000000
# 50%      36.000000     0.000000        2.000000   447.000000     1.000000
# 75%      43.000000     0.000000        2.000000   660.000000     2.000000
# max      60.000000     1.000000        2.000000   885.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeCount  \
# count       1470.000000  1470.000000     1470.000000         1470.0
# mean           9.192517     2.912925        2.247619            1.0
# std            8.106864     1.024165        1.331369            0.0
# ...

# %%
# Observation
# on missing values
# data is catagorical data

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
# cheking & confirm data is normal distributed
plt.figure(figsize=(12,14),facecolor='y')
plotnumber=1
for i in dt:
    if plotnumber<=36:
        plt.subplot(4,9,plotnumber)
        ax=sns.distplot(dt[i])
        plt.xlabel(i,fontsize=10)
        
    plotnumber+=1
    
plt.show()

# %%
# cheking Outlier using box plot.
plt.figure(figsize=(12,14))
plotnumber=1
for column in dt:
    if plotnumber<=36:
        ax=plt.subplot(4,9,plotnumber)
        sns.boxplot(dt[column])
        plt.xlabel(column, fontsize=10)
        
    plotnumber+=1
plt.show()

# %%
dt.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# observation
# MonthlyIncome,MonthlyRate,StockOptionLevel,TotalWorkingYears,TrainingTimesLastYear,YearsAtCompany,YearsInCurrentRole,YearsSinceLastPromotion,YearsWithCurrManager comuns has outlier.
# will handel outlier

# %%
# for getting iqr

q3=dt.quantile(0.75)
q1=dt.quantile(0.25)
iqr=q3-q1

# %%
#  handle Outlir MonthlyIncome column
higher_MonthlyIncome=q3.MonthlyIncome+(1.5*iqr.MonthlyIncome)  # find hiher side outlier
print('higher side   >',higher_MonthlyIncome)

index=np.where(dt['MonthlyIncome']>higher_MonthlyIncome)     # find index number of higher outlier
dt=dt.drop(dt.index[index])          # drop the index
dt.reset_index()                     # reset index of data
dt.shape                             # shape the data
# Out:
# higher side   > 16581.0
# (1356, 35)

# %%
#  handle Outlir MonthlyRate column
higher_MonthlyRate=q3.MonthlyRate+(1.5*iqr.MonthlyRate)  # find hiher side outlier
print('higher side   >',higher_MonthlyRate)

index=np.where(dt['MonthlyRate']>higher_MonthlyRate)     # find index number of higher outlier
dt=dt.drop(dt.index[index])          # drop the index
dt.reset_index()                     # reset index of data
dt.shape
# Out:
# higher side   > 39083.25
# (1356, 35)

# %%
#  handle Outlir StockOptionLevel column
higher_StockOptionLevel=q3.StockOptionLevel+(1.5*iqr.StockOptionLevel)  # find hiher side outlier
print('higher side   >',higher_StockOptionLevel)

index=np.where(dt['StockOptionLevel']>higher_StockOptionLevel)     # find index number of higher outlier
dt=dt.drop(dt.index[index])          # drop the index
dt.reset_index()                     # reset index of data
dt.shape
# Out:
# higher side   > 2.5
# (1274, 35)

# %%
#  handle Outlir TotalWorkingYears column
higher_TotalWorkingYears=q3.TotalWorkingYears+(1.5*iqr.TotalWorkingYears)  # find hiher side outlier
print('higher side   >',higher_TotalWorkingYears)

index=np.where(dt['TotalWorkingYears']>higher_TotalWorkingYears)     # find index number of higher outlier
dt=dt.drop(dt.index[index])          # drop the index
dt.reset_index()                     # reset index of data
dt.shape
# Out:
# higher side   > 28.5
# (1246, 35)

# %%
#  handle Outlir TrainingTimesLastYear column
higher_TrainingTimesLastYear=q3.TrainingTimesLastYear+(1.5*iqr.TrainingTimesLastYear)  # find hiher side outlier
print('higher side   >',higher_TrainingTimesLastYear)

index=np.where(dt['TrainingTimesLastYear']>higher_TrainingTimesLastYear)     # find index number of higher outlier
dt=dt.drop(dt.index[index])          # drop the index
dt.reset_index()                     # reset index of data
dt.shape
# Out:
# higher side   > 4.5
# (1085, 35)

# %%
#  handle Outlir YearsAtCompany column
higher_YearsAtCompany=q3.YearsAtCompany+(1.5*iqr.YearsAtCompany)  # find hiher side outlier
print('higher side   >',higher_YearsAtCompany)

index=np.where(dt['YearsAtCompany']>higher_YearsAtCompany)     # find index number of higher outlier
dt=dt.drop(dt.index[index])          # drop the index
dt.reset_index()                     # reset index of data
dt.shape
# Out:
# higher side   > 18.0
# (1047, 35)

# %%
#  handle Outlir YearsInCurrentRole column
higher_YearsInCurrentRole=q3.YearsInCurrentRole+(1.5*iqr.YearsInCurrentRole)  # find hiher side outlier
print('higher side   >',higher_YearsInCurrentRole)

index=np.where(dt['YearsInCurrentRole']>higher_YearsInCurrentRole)     # find index number of higher outlier
dt=dt.drop(dt.index[index])          # drop the index
dt.reset_index()                     # reset index of data
dt.shape
# Out:
# higher side   > 14.5
# (1044, 35)

# %%
#  handle Outlir YearsSinceLastPromotion column
higher_YearsSinceLastPromotion=q3.YearsSinceLastPromotion+(1.5*iqr.YearsSinceLastPromotion)  # find hiher side outlier
print('higher side   >',higher_YearsSinceLastPromotion)

index=np.where(dt['YearsSinceLastPromotion']>higher_YearsSinceLastPromotion)     # find index number of higher outlier
dt=dt.drop(dt.index[index])          # drop the index
dt.reset_index()                     # reset index of data
dt.shape
# Out:
# higher side   > 7.5
# (1008, 35)

# %%
#  handle Outlir YearsWithCurrManager column
higher_YearsWithCurrManager=q3.YearsWithCurrManager+(1.5*iqr.YearsWithCurrManager)  # find hiher side outlier
print('higher side   >',higher_YearsWithCurrManager)

index=np.where(dt['YearsWithCurrManager']>higher_YearsWithCurrManager)     # find index number of higher outlier
dt=dt.drop(dt.index[index])          # drop the index
dt.reset_index()                     # reset index of data
dt.shape
# Out:
# higher side   > 14.5
# (1005, 35)

# %%
# noe data has Row No-1005& columns 35 after trit the uotlier

# %%
# cheking Outlier using box plot.
plt.figure(figsize=(12,14))
plotnumber=1
for column in dt:
    if plotnumber<=36:
        ax=plt.subplot(4,9,plotnumber)
        sns.boxplot(dt[column])
        plt.xlabel(column, fontsize=10)
        
    plotnumber+=1
plt.show()

# %%
# Observation: Now Minimize the outlier

# %%
# Checking data distributed

plt.figure(figsize=(12,14),facecolor='y')
plotnumber=1
for column in dt:
    if plotnumber<=36:
        ax=plt.subplot(4,9,plotnumber)
        sns.distplot(dt[column])
        plt.xlabel(column, fontsize=7)
        
    plotnumber+=1
plt.show()

# %%
dt.dropna()
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2        624           2                 1
# 1      49          0               1        113           1                 8
# 2      37          1               2        805           1                 2
# 3      33          0               1        820           1                 3
# 4      27          0               2        312           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1464   26          0               2        663           2                 5
# 1465   36          0               1        494           1                23
# 1467   27          0               2         39           1                 4
# 1468   49          0               1        579           2                 2
# 1469   34          0               2        336           1                 8
#
# ...

# %%
dt.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
dt.corr().abs()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000   0.157644        0.008771   0.017277
# Attrition                 0.157644   1.000000        0.017060   0.061097
# BusinessTravel            0.008771   0.017060        1.000000   0.022300
# DailyRate                 0.017277   0.061097        0.022300   1.000000
# Department                0.012221   0.060262        0.025487   0.027887
# DistanceFromHome          0.025308   0.086031        0.030121   0.006105
# Education                 0.215519   0.048106        0.007114   0.050955
# EducationField            0.034826   0.036897        0.002761   0.042963
# EmployeeCount                  NaN        NaN             NaN        NaN
# EmployeeNumber            0.015626   0.007216        0.043371   0.044405
# EnvironmentSatisfaction   0.003503   0.105247        0.004065   0.053281
# Gender                    0.028353   0.026120        0.035051   0.026570
# ...

# %%
dt=dt.drop(['EmployeeCount'],axis=1)

# %%
dt
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2        624           2                 1
# 1      49          0               1        113           1                 8
# 2      37          1               2        805           1                 2
# 3      33          0               1        820           1                 3
# 4      27          0               2        312           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1464   26          0               2        663           2                 5
# 1465   36          0               1        494           1                23
# 1467   27          0               2         39           1                 4
# 1468   49          0               1        579           2                 2
# 1469   34          0               2        336           1                 8
#
# ...
